# %% [markdown]
# # Repo test
#
# This notebook is to test the repo CI functionality. If you commit this notebook with outputs and make a PR, you shouldn't be able to merge the PR because the CI / lint action should fail.

# %%
1 + 1
